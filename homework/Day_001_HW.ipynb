# %% [markdown]
# ##作業1
# 我所選擇的資料為Heart Disease UCI，以下為資料網址:https://www.kaggle.com/ronitf/heart-disease-uci
# 1. Q:你選的這組資料為何重要
# A:我認為本資料對於人類健康疾病的預防有相當大的關係，經由解析本資料可以了解甚麼樣的族群需要更加堤防心臟疾病。
#
# 2. Q:資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A:根據網站上所示，資料來源來自於許多家醫院的病歷。
#
# 3. Q:蒐集而來的資料型態為何
# A:資料是CSV檔，為結構化資料。
#
# 4. Q:這組資料想解決的問題如何評估
# A:本組資料可以利用分類的方式，觀察在何種情況下，哪幾種屬性對於預測心臟病發生的可能性有密切關系。
#
# ##作業2
# 1. Q:核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A:經營一自由載客車隊所要面臨到最大的困難點在於如何與廣大的職業計程車對抗。
# 所以除了提升載客率以外，也要降低同車隊在相同區域載客的可能。
#
# 2. Q:資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A:在司機的車上裝置導航或者手機建置軟體，將所有車輛每天行駛的路線，以及載客數量資料彙整。
#
# 3. Q:蒐集而來的資料型態為何
# A:為結構化資料
#
# 4. Q:你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A:經由分析後的結果，可以重新配車，驗證同公司間車輛是否都沒有在同一區域打轉。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=MSE = sum((y-yp)**2)/len(y)

    return mse
def mean_absolute_error(y, yp):
    
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 220.681
# The Mean absolute error is 12.200
